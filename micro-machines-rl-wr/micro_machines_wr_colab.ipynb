# %% [markdown]
# # 🏎️ Finny Tech Deep Labs - Micro Machines 2 World Record RL (JAX/Flax on TPU v5e-1)
# Reinforcement Learning Training mit Custom Causal Transformer Policy, RAM-State Reverse Engineering, Live Stream & World Record Tracker.

# %%
# 1. Setup TPU & Dependencies
# !pip install -q jax[tpu] flax optax opencv-python gym-retro stable-retro
# !wget -q -nc https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 -O cloudflared
# !chmod +x cloudflared

import jax
print("JAX Devices:", jax.devices())

# %%
# 2. Start the Training & Live Stream
# Clone or run our training scripts directly
# !python3 train.py
